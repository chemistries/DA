# %%
import numpy as np
import pandas as pd

# %%
admin = pd.read_excel('C:\\Users\\lzh-a\\Desktop\DA\\NZ_Admin_JOBS.xlsx')

# %%
admin.describe()
# Out:
#                         字段1  \
# count                  2708
# unique                  548
# top     Executive Assistant
# freq                    301
#
#                                                  字段1_link  \
# count                                                2708
# unique                                               2708
# top     https://www.seek.co.nz/job/50582301?type=promo...
# freq                                                    1
#
#                                                       字段2  \
# count                                                2686
# unique                                                475
# top     Beyond Recruitment - Winner – Best Innovation ...
# freq                                                  285
#
#                                                       字段3         字段4  \
# count                                                2708        2708
# unique                                                147          54
# ...

# %%
admin.head(5)
# Out:
#                                     字段1  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                             字段1_link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                         字段2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                  字段3  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# ...

# %%
admin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   字段1       2708 non-null   object
#  1   字段1_link  2708 non-null   object
#  2   字段2       2686 non-null   object
#  3   字段3       2708 non-null   object
#  4   字段4       2708 non-null   object
#  5   字段5       2708 non-null   object
# dtypes: object(6)
# memory usage: 127.1+ KB

# %%
admin.columns = ['Position', 'Link', 'Company', 'Location', 'Post Time', 'Classification']

# %%
admin.head()
# Out:
#                                Position  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                 Link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Company  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                             Location  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# ...

# %%
df1 = admin['Location'].str.split('location: ', expand = True)
df1
df2 = df1[0].str.split('area: ', expand = True)
df2
# Out:
#                                0  \
# 0     Bay of PlentyBay of Plenty
# 1     Bay of PlentyBay of Plenty
# 2               AucklandAuckland
# 3             SouthlandSouthland
# 4           CanterburyCanterbury
# ...                          ...
# 2703            AucklandAuckland
# 2704        WellingtonWellington
# 2705              WaikatoWaikato
# 2706              WaikatoWaikato
# 2707        WellingtonWellington
#
#                                                       1
# 0                                      TaurangaTauranga
# 1                                      TaurangaTauranga
# 2                                                  None
# 3                              InvercargillInvercargill
# 4                              ChristchurchChristchurch
# ...                                                 ...
# 2703                   Auckland CentralAuckland Central
# 2704  Wellington CentralWellington Central,Competiti...
# ...

# %%
admin['Location'] = df2[0]
admin['Area'] = df2[1]

# %%
admin.head()
# Out:
#                                Position  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                 Link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Company                    Location  \
# 0                                       NaN  Bay of PlentyBay of Plenty
# 1                      Avenues Orthodontics  Bay of PlentyBay of Plenty
# 2                        New Zealand Police            AucklandAuckland
# 3  Kew Pacific Island Early Learning Centre          SouthlandSouthland
# ...

# %%
df3 = admin['Classification'].str.split('classification: ', expand = True)
df3
# Out:
#                                 0  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...
# 2703
# 2704      Competitive hourly rate
# 2705  Competitive hourly rates $$
# 2706  Competitive hourly rates $$
# 2707
#
#                                                       1
# 0     Administration & Office SupportAdministration ...
# 1     Administration & Office SupportAdministration ...
# 2     Administration & Office SupportAdministration ...
# 3     Administration & Office SupportAdministration ...
# 4     Administration & Office SupportAdministration ...
# ...                                                 ...
# 2703  Administration & Office SupportAdministration ...
# 2704                                               None
# 2705                                               None
# 2706                                               None
# 2707  Administration & Office SupportAdministration ...
#
# [2708 rows x 2 columns]

# %%
df4 = df3[1].str.split('subClassification: ', expand = True)
df4
# Out:
#                                                       0  \
# 0     Administration & Office SupportAdministration ...
# 1     Administration & Office SupportAdministration ...
# 2     Administration & Office SupportAdministration ...
# 3     Administration & Office SupportAdministration ...
# 4     Administration & Office SupportAdministration ...
# ...                                                 ...
# 2703  Administration & Office SupportAdministration ...
# 2704                                               None
# 2705                                               None
# 2706                                               None
# 2707  Administration & Office SupportAdministration ...
#
#                                                       1
# 0                    Office ManagementOffice Management
# 1                            ReceptionistsReceptionists
# 2                                            OtherOther
# 3     Administrative AssistantsAdministrative Assist...
# ...

# %%
admin['Classification'] = df4[0]
admin['SubClassification'] = df4[1]
admin['Salary'] = df3[0]
admin.head()
# Out:
#                                Position  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                 Link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Company                    Location  \
# 0                                       NaN  Bay of PlentyBay of Plenty
# 1                      Avenues Orthodontics  Bay of PlentyBay of Plenty
# 2                        New Zealand Police            AucklandAuckland
# 3  Kew Pacific Island Early Learning Centre          SouthlandSouthland
# ...
